# %%
# !git clone https://github.com/KwaiVGI/LivePortrait.git
# Out:
# Cloning into 'LivePortrait'...
# remote: Enumerating objects: 1071, done.
# remote: Counting objects: 100% (293/293), done.
# remote: Compressing objects: 100% (47/47), done.
# remote: Total 1071 (delta 261), reused 246 (delta 246), pack-reused 778 (from 3)
# Receiving objects: 100% (1071/1071), 38.76 MiB | 19.52 MiB/s, done.
# Resolving deltas: 100% (545/545), done.

# %%
# %cd LivePortrait
# Out:
# /content/LivePortrait

# %%
# !pip install -q torch torchvision imageio opencv-python gdown dlib
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 66.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 92.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 52.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 11.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 65.2 MB/s eta 0:00:00

# %%
# !pip install tyro
# Out:
# Collecting tyro
#   Downloading tyro-0.9.24-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: docstring-parser>=0.15 in /usr/local/lib/python3.11/dist-packages (from tyro) (0.16)
# Requirement already satisfied: rich>=11.1.0 in /usr/local/lib/python3.11/dist-packages (from tyro) (13.9.4)
# Collecting shtab>=1.5.6 (from tyro)
#   Downloading shtab-1.7.2-py3-none-any.whl.metadata (7.4 kB)
# Requirement already satisfied: typeguard>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from tyro) (4.4.2)
# Requirement already satisfied: typing-extensions>=4.13.0 in /usr/local/lib/python3.11/dist-packages (from tyro) (4.13.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=11.1.0->tyro) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich>=11.1.0->tyro) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=11.1.0->tyro) (0.1.2)
# Downloading tyro-0.9.24-py3-none-any.whl (128 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.3/128.3 kB 6.5 MB/s eta 0:00:00
# Downloading shtab-1.7.2-py3-none-any.whl (14 kB)
# Installing collected packages: shtab, tyro
# Successfully installed shtab-1.7.2 tyro-0.9.24

# %%
# !pip install torch torchvision opencv-python imageio gdown dlib tyro onnx onnxruntime ffmpeg-python
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (2.6.0+cu124)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/dist-packages (0.21.0+cu124)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.11/dist-packages (4.11.0.86)
# Requirement already satisfied: imageio in /usr/local/lib/python3.11/dist-packages (2.37.0)
# Requirement already satisfied: gdown in /usr/local/lib/python3.11/dist-packages (5.2.0)
# Requirement already satisfied: dlib in /usr/local/lib/python3.11/dist-packages (19.24.6)
# Requirement already satisfied: tyro in /usr/local/lib/python3.11/dist-packages (0.9.24)
# Collecting onnx
#   Downloading onnx-1.18.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.9 kB)
# Collecting onnxruntime
#   Downloading onnxruntime-1.22.0-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (4.5 kB)
# Collecting ffmpeg-python
#   Downloading ffmpeg_python-0.2.0-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch) (4.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch) (2025.3.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from torchvision) (2.0.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from torchvision) (11.2.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (from gdown) (4.13.4)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.11/dist-packages (from gdown) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from gdown) (4.67.1)
# Requirement already satisfied: docstring-parser>=0.15 in /usr/local/lib/python3.11/dist-packages (from tyro) (0.16)
# Requirement already satisfied: rich>=11.1.0 in /usr/local/lib/python3.11/dist-packages (from tyro) (13.9.4)
# Requirement already satisfied: shtab>=1.5.6 in /usr/local/lib/python3.11/dist-packages (from tyro) (1.7.2)
# Requirement already satisfied: typeguard>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from tyro) (4.4.2)
# Requirement already satisfied: protobuf>=4.25.1 in /usr/local/lib/python3.11/dist-packages (from onnx) (5.29.5)
# Collecting coloredlogs (from onnxruntime)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.11/dist-packages (from onnxruntime) (25.2.10)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from onnxruntime) (24.2)
# Requirement already satisfied: future in /usr/local/lib/python3.11/dist-packages (from ffmpeg-python) (1.0.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=11.1.0->tyro) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich>=11.1.0->tyro) (2.19.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->gdown) (2.7)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (2025.4.26)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (1.7.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=11.1.0->tyro) (0.1.2)
# Downloading onnx-1.18.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.6/17.6 MB 48.4 MB/s eta 0:00:00
# Downloading onnxruntime-1.22.0-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 38.5 MB/s eta 0:00:00
# Downloading ffmpeg_python-0.2.0-py3-none-any.whl (25 kB)
# Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 3.4 MB/s eta 0:00:00
# Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 7.8 MB/s eta 0:00:00
# Installing collected packages: onnx, humanfriendly, ffmpeg-python, coloredlogs, onnxruntime
# Successfully installed coloredlogs-15.0.1 ffmpeg-python-0.2.0 humanfriendly-10.0 onnx-1.18.0 onnxruntime-1.22.0

# %%
# !apt-get install git-lfs
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# git-lfs is already the newest version (3.0.2-1ubuntu0.3).
# 0 upgraded, 0 newly installed, 0 to remove and 35 not upgraded.

# %%
# !git lfs install
# Out:
# Updated git hooks.
# Git LFS initialized.

# %%
# !rm -rf pretrained_weights

# %%
# !git clone https://huggingface.co/KwaiVGI/liveportrait pretrained_weights
# Out:
# Cloning into 'pretrained_weights'...
# remote: Enumerating objects: 90, done.
# remote: Counting objects: 100% (14/14), done.
# remote: Compressing objects: 100% (14/14), done.
# remote: Total 90 (delta 3), reused 0 (delta 0), pack-reused 76 (from 1)
# Unpacking objects: 100% (90/90), 23.50 KiB | 891.00 KiB/s, done.
# Filtering content: 100% (20/20), 1.99 GiB | 73.51 MiB/s, done.

# %%
# !ls pretrained_weights/liveportrait/base_models
# Out:
# appearance_feature_extractor.pth  spade_generator.pth
# motion_extractor.pth		  warping_module.pth

# %%
# !pip uninstall numpy
# Out:
# Found existing installation: numpy 2.0.2
# Uninstalling numpy-2.0.2:
#   Would remove:
#     /usr/local/bin/f2py
#     /usr/local/bin/numpy-config
#     /usr/local/lib/python3.11/dist-packages/numpy-2.0.2.dist-info/*
#     /usr/local/lib/python3.11/dist-packages/numpy.libs/libgfortran-040039e1-0352e75f.so.5.0.0
#     /usr/local/lib/python3.11/dist-packages/numpy.libs/libquadmath-96973f99-934c22de.so.0.0.0
#     /usr/local/lib/python3.11/dist-packages/numpy.libs/libscipy_openblas64_-99b71e71.so
#     /usr/local/lib/python3.11/dist-packages/numpy/*
# Proceed (Y/n)? y
#   Successfully uninstalled numpy-2.0.2

# %%
# !pip install numpy==1.26.4
# Out:
# Collecting numpy==1.26.4
#   Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 4.8 MB/s eta 0:00:00
# Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 106.0 MB/s eta 0:00:00
# Installing collected packages: numpy
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# Successfully installed numpy-1.26.4

# %%
# !git lfs install
# Out:
# Updated git hooks.
# Git LFS initialized.

# %%
# Run this cell, if you need to got any error cell [9] or got any other type of error
# !pip install --force-reinstall onnxruntime
# Out:
# Collecting onnxruntime
#   Using cached onnxruntime-1.22.0-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (4.5 kB)
# Collecting coloredlogs (from onnxruntime)
#   Using cached coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Collecting flatbuffers (from onnxruntime)
#   Downloading flatbuffers-25.2.10-py2.py3-none-any.whl.metadata (875 bytes)
# Collecting numpy>=1.21.6 (from onnxruntime)
#   Downloading numpy-2.2.6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 3.8 MB/s eta 0:00:00
# Collecting packaging (from onnxruntime)
#   Downloading packaging-25.0-py3-none-any.whl.metadata (3.3 kB)
# ERROR: Operation cancelled by user

# %%
# !pip install pykalman
# Out:
# Collecting pykalman
#   Downloading pykalman-0.10.1-py2.py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: numpy<3 in /usr/local/lib/python3.11/dist-packages (from pykalman) (1.26.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from pykalman) (24.2)
# Collecting scikit-base<0.13.0 (from pykalman)
#   Downloading scikit_base-0.12.3-py3-none-any.whl.metadata (8.8 kB)
# Requirement already satisfied: scipy<2.0.0 in /usr/local/lib/python3.11/dist-packages (from pykalman) (1.15.3)
# Downloading pykalman-0.10.1-py2.py3-none-any.whl (248 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 248.5/248.5 kB 9.9 MB/s eta 0:00:00
# Downloading scikit_base-0.12.3-py3-none-any.whl (145 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 145.5/145.5 kB 2.0 MB/s eta 0:00:00
# Installing collected packages: scikit-base, pykalman
# Successfully installed pykalman-0.10.1 scikit-base-0.12.3

# %%
# !python inference.py -s assets/examples/source/s9.jpg -d assets/examples/driving/d0.mp4
# Out:
# [14:00:29] Load appearance_feature_extractor from    ]8;id=564507;file:///content/LivePortrait/src/live_portrait_wrapper.py\live_portrait_wrapper.py]8;;\:]8;id=252006;file:///content/LivePortrait/src/live_portrait_wrapper.py#46\46]8;;\
#            /content/LivePortrait/pretrained_weights/
#            liveportrait/base_models/appearance_featu
#            re_extractor.pth done.
#            Load motion_extractor from                ]8;id=789728;file:///content/LivePortrait/src/live_portrait_wrapper.py\live_portrait_wrapper.py]8;;\:]8;id=698771;file:///content/LivePortrait/src/live_portrait_wrapper.py#49\49]8;;\
#            /content/LivePortrait/pretrained_weights/
#            liveportrait/base_models/motion_extractor
#            .pth done.
# [14:00:30] Load warping_module from                  ]8;id=504670;file:///content/LivePortrait/src/live_portrait_wrapper.py\live_portrait_wrapper.py]8;;\:]8;id=813532;file:///content/LivePortrait/src/live_portrait_wrapper.py#52\52]8;;\
#            /content/LivePortrait/pretrained_weights/
#            liveportrait/base_models/warping_module.p
#            th done.
#            Load spade_generator from                 ]8;id=607783;file:///content/LivePortrait/src/live_portrait_wrapper.py\live_portrait_wrapper.py]8;;\:]8;id=548753;file:///content/LivePortrait/src/live_portrait_wrapper.py#55\55]8;;\
#            /content/LivePortrait/pretrained_weights/
#            liveportrait/base_models/spade_generator.
#            pth done.
#            Load stitching_retargeting_module from    ]8;id=559284;file:///content/LivePortrait/src/live_portrait_wrapper.py\live_portrait_wrapper.py]8;;\:]8;id=27366;file:///content/LivePortrait/src/live_portrait_wrapper.py#59\59]8;;\
#            /content/LivePortrait/pretrained_weights/
#            liveportrait/retargeting_models/stitching
#            _retargeting_module.pth done.
# /usr/local/lib/python3.11/dist-packages/onnxruntime/capi/onnxruntime_inference_collection.py:121: UserWarning: Specified provider 'CUDAExecutionProvider' is not in available provider names.Available providers: 'AzureExecutionProvider, CPUExecutionProvider'
#   warnings.warn(
# [14:00:31] FaceAnalysisDIY warmup time: 0.252s           ]8;id=496158;file:///content/LivePortrait/src/utils/face_analysis_diy.py\face_analysis_diy.py]8;;\:]8;id=137325;file:///content/LivePortrait/src/utils/face_analysis_diy.py#79\79]8;;\
#            LandmarkRunner warmup time: 0.129s        ]8;id=103246;file:///content/LivePortrait/src/utils/human_landmark_runner.py\human_landmark_runner.py]8;;\:]8;id=442111;file:///content/LivePortrait/src/utils/human_landmark_runner.py#95\95]8;;\
#            Load source image from                   ]8;id=302134;file:///content/LivePortrait/src/live_portrait_pipeline.py\live_portrait_pipeline.py]8;;\:]8;id=282179;file:///content/LivePortrait/src/live_portrait_pipeline.py#90\90]8;;\
#            assets/examples/source/s9.jpg
#            Load driving video from:                ]8;id=718086;file:///content/LivePortrait/src/live_portrait_pipeline.py\live_portrait_pipeline.py]8;;\:]8;id=526896;file:///content/LivePortrait/src/live_portrait_pipeline.py#133\133]8;;\
#            assets/examples/driving/d0.mp4, FPS is
#            25
# [14:00:32] Start making driving motion template... ]8;id=939723;file:///content/LivePortrait/src/live_portrait_pipeline.py\live_portrait_pipeline.py]8;;\:]8;id=998336;file:///content/LivePortrait/src/live_portrait_pipeline.py#144\144]8;;\
# Making motion templates... ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:03
# [14:00:50] Dump motion template to                 ]8;id=995587;file:///content/LivePortrait/src/live_portrait_pipeline.py\live_portrait_pipeline.py]8;;\:]8;id=681813;file:///content/LivePortrait/src/live_portrait_pipeline.py#172\172]8;;\
#            assets/examples/driving/d0.pkl
#            Prepared pasteback mask done.           ]8;id=361469;file:///content/LivePortrait/src/live_portrait_pipeline.py\live_portrait_pipeline.py]8;;\:]8;id=420189;file:///content/LivePortrait/src/live_portrait_pipeline.py#183\183]8;;\
# [14:00:51] The animated video consists of 78       ]8;id=947322;file:///content/LivePortrait/src/live_portrait_pipeline.py\live_portrait_pipeline.py]8;;\:]8;id=805797;file:///content/LivePortrait/src/live_portrait_pipeline.py#270\270]8;;\
#            frames.
# 🚀Animating... ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:13
# Concatenating result... ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
# Writing ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
# Writing ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
# [14:01:12] Animated template:                      ]8;id=832178;file:///content/LivePortrait/src/live_portrait_pipeline.py\live_portrait_pipeline.py]8;;\:]8;id=792728;file:///content/LivePortrait/src/live_portrait_pipeline.py#503\503]8;;\
#            assets/examples/driving/d0.pkl, you can
#            specify `-d` argument with this
#            template path next time to avoid
#            cropping video, motion making and
#            protecting privacy.
#            Animated video: animations/s9--d0.mp4   ]8;id=498101;file:///content/LivePortrait/src/live_portrait_pipeline.py\live_portrait_pipeline.py]8;;\:]8;id=693165;file:///content/LivePortrait/src/live_portrait_pipeline.py#504\504]8;;\
#            Animated video with concat:             ]8;id=326306;file:///content/LivePortrait/src/live_portrait_pipeline.py\live_portrait_pipeline.py]8;;\:]8;id=733601;file:///content/LivePortrait/src/live_portrait_pipeline.py#505\505]8;;\
#            animations/s9--d0_concat.mp4

# %%
# %%writefile inference.py
# coding: utf-8
"""
The entrance of humans
"""

import os
import os.path as osp
import tyro
import subprocess
import time
import sys
from src.config.argument_config import ArgumentConfig
from src.config.inference_config import InferenceConfig
from src.config.crop_config import CropConfig
from src.live_portrait_pipeline import LivePortraitPipeline


def partial_fields(target_class, kwargs):
    return target_class(**{k: v for k, v in kwargs.items() if hasattr(target_class, k)})


def fast_check_ffmpeg():
    try:
        subprocess.run(["ffmpeg", "-version"], capture_output=True, check=True)
        return True
    except Exception as e:
        print(f"❌ FFmpeg check failed: {e}")
        sys.stdout.flush()
        return False


def fast_check_args(args: ArgumentConfig):
    if not osp.exists(args.source):
        raise FileNotFoundError(f"source info not found: {args.source}")
    if not osp.exists(args.driving):
        raise FileNotFoundError(f"driving info not found: {args.driving}")


def main():
    # set tyro theme
    tyro.extras.set_accent_color("bright_cyan")
    args = tyro.cli(ArgumentConfig)

    ffmpeg_dir = os.path.join(os.getcwd(), "ffmpeg")
    if osp.exists(ffmpeg_dir):
        os.environ["PATH"] += (os.pathsep + ffmpeg_dir)

    if not fast_check_ffmpeg():
        raise ImportError("FFmpeg is not installed. Please install it: https://ffmpeg.org/download.html")

    fast_check_args(args)

    # specify configs for inference
    inference_cfg = partial_fields(InferenceConfig, args.__dict__)
    crop_cfg = partial_fields(CropConfig, args.__dict__)

    live_portrait_pipeline = LivePortraitPipeline(
        inference_cfg=inference_cfg,
        crop_cfg=crop_cfg
    )

    try:
        print("⚠️ BEFORE EXECUTE")
        sys.stdout.flush()

        start_time = time.time()
        live_portrait_pipeline.execute(args)
        end_time = time.time()

        print("⚠️ AFTER EXECUTE")
        sys.stdout.flush()

        print(f"✅ Inference Time: {end_time - start_time:.2f} seconds")
        sys.stdout.flush()

        # Also write to file in case stdout is broken
        with open("log.txt", "w") as f:
            f.write(f"Inference Time: {end_time - start_time:.2f} seconds\n")

    except Exception as e:
        print(f"❌ CRASHED during execution: {repr(e)}")
        sys.stdout.flush()
        with open("log.txt", "w") as f:
            f.write(f"Execution failed: {repr(e)}\n")


if __name__ == "__main__":
    main()
# Out:
# Overwriting inference.py

# %%
# !python inference.py -s assets/examples/source/s9.jpg -d assets/examples/driving/d0.mp4
# Out:
# [14:03:19] Load appearance_feature_extractor from    ]8;id=402530;file:///content/LivePortrait/src/live_portrait_wrapper.py\live_portrait_wrapper.py]8;;\:]8;id=23018;file:///content/LivePortrait/src/live_portrait_wrapper.py#46\46]8;;\
#            /content/LivePortrait/pretrained_weights/
#            liveportrait/base_models/appearance_featu
#            re_extractor.pth done.
#            Load motion_extractor from                ]8;id=611585;file:///content/LivePortrait/src/live_portrait_wrapper.py\live_portrait_wrapper.py]8;;\:]8;id=765673;file:///content/LivePortrait/src/live_portrait_wrapper.py#49\49]8;;\
#            /content/LivePortrait/pretrained_weights/
#            liveportrait/base_models/motion_extractor
#            .pth done.
# [14:03:20] Load warping_module from                  ]8;id=240431;file:///content/LivePortrait/src/live_portrait_wrapper.py\live_portrait_wrapper.py]8;;\:]8;id=758672;file:///content/LivePortrait/src/live_portrait_wrapper.py#52\52]8;;\
#            /content/LivePortrait/pretrained_weights/
#            liveportrait/base_models/warping_module.p
#            th done.
#            Load spade_generator from                 ]8;id=403613;file:///content/LivePortrait/src/live_portrait_wrapper.py\live_portrait_wrapper.py]8;;\:]8;id=533049;file:///content/LivePortrait/src/live_portrait_wrapper.py#55\55]8;;\
#            /content/LivePortrait/pretrained_weights/
#            liveportrait/base_models/spade_generator.
#            pth done.
#            Load stitching_retargeting_module from    ]8;id=90304;file:///content/LivePortrait/src/live_portrait_wrapper.py\live_portrait_wrapper.py]8;;\:]8;id=695961;file:///content/LivePortrait/src/live_portrait_wrapper.py#59\59]8;;\
#            /content/LivePortrait/pretrained_weights/
#            liveportrait/retargeting_models/stitching
#            _retargeting_module.pth done.
# /usr/local/lib/python3.11/dist-packages/onnxruntime/capi/onnxruntime_inference_collection.py:121: UserWarning: Specified provider 'CUDAExecutionProvider' is not in available provider names.Available providers: 'AzureExecutionProvider, CPUExecutionProvider'
#   warnings.warn(
# [14:03:21] FaceAnalysisDIY warmup time: 0.255s           ]8;id=65556;file:///content/LivePortrait/src/utils/face_analysis_diy.py\face_analysis_diy.py]8;;\:]8;id=542775;file:///content/LivePortrait/src/utils/face_analysis_diy.py#79\79]8;;\
#            LandmarkRunner warmup time: 0.129s        ]8;id=772744;file:///content/LivePortrait/src/utils/human_landmark_runner.py\human_landmark_runner.py]8;;\:]8;id=357121;file:///content/LivePortrait/src/utils/human_landmark_runner.py#95\95]8;;\
# ⚠️ BEFORE EXECUTE
#            Load source image from                   ]8;id=821316;file:///content/LivePortrait/src/live_portrait_pipeline.py\live_portrait_pipeline.py]8;;\:]8;id=978618;file:///content/LivePortrait/src/live_portrait_pipeline.py#90\90]8;;\
#            assets/examples/source/s9.jpg
#            Load driving video from:                ]8;id=748158;file:///content/LivePortrait/src/live_portrait_pipeline.py\live_portrait_pipeline.py]8;;\:]8;id=482144;file:///content/LivePortrait/src/live_portrait_pipeline.py#133\133]8;;\
#            assets/examples/driving/d0.mp4, FPS is
#            25
# [14:03:22] Start making driving motion template... ]8;id=242811;file:///content/LivePortrait/src/live_portrait_pipeline.py\live_portrait_pipeline.py]8;;\:]8;id=161759;file:///content/LivePortrait/src/live_portrait_pipeline.py#144\144]8;;\
# Making motion templates... ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:02
# [14:03:39] Dump motion template to                 ]8;id=205318;file:///content/LivePortrait/src/live_portrait_pipeline.py\live_portrait_pipeline.py]8;;\:]8;id=656285;file:///content/LivePortrait/src/live_portrait_pipeline.py#172\172]8;;\
#            assets/examples/driving/d0.pkl
#            Prepared pasteback mask done.           ]8;id=708076;file:///content/LivePortrait/src/live_portrait_pipeline.py\live_portrait_pipeline.py]8;;\:]8;id=552948;file:///content/LivePortrait/src/live_portrait_pipeline.py#183\183]8;;\
# [14:03:40] The animated video consists of 78       ]8;id=474954;file:///content/LivePortrait/src/live_portrait_pipeline.py\live_portrait_pipeline.py]8;;\:]8;id=96009;file:///content/LivePortrait/src/live_portrait_pipeline.py#270\270]8;;\
#            frames.
# 🚀Animating... ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:13
# Concatenating result... ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
# Writing ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
# Writing ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
# [14:03:59] Animated template:                      ]8;id=176065;file:///content/LivePortrait/src/live_portrait_pipeline.py\live_portrait_pipeline.py]8;;\:]8;id=256526;file:///content/LivePortrait/src/live_portrait_pipeline.py#503\503]8;;\
#            assets/examples/driving/d0.pkl, you can
#            specify `-d` argument with this
#            template path next time to avoid
#            cropping video, motion making and
#            protecting privacy.
#            Animated video: animations/s9--d0.mp4   ]8;id=974713;file:///content/LivePortrait/src/live_portrait_pipeline.py\live_portrait_pipeline.py]8;;\:]8;id=618508;file:///content/LivePortrait/src/live_portrait_pipeline.py#504\504]8;;\
#            Animated video with concat:             ]8;id=709481;file:///content/LivePortrait/src/live_portrait_pipeline.py\live_portrait_pipeline.py]8;;\:]8;id=710591;file:///content/LivePortrait/src/live_portrait_pipeline.py#505\505]8;;\
#            animations/s9--d0_concat.mp4
# ⚠️ AFTER EXECUTE
# ✅ Inference Time: 37.86 seconds

# %%
# !python -u inference.py
# Out:
# [14:06:24] Load appearance_feature_extractor from    ]8;id=340112;file:///content/LivePortrait/src/live_portrait_wrapper.py\live_portrait_wrapper.py]8;;\:]8;id=282693;file:///content/LivePortrait/src/live_portrait_wrapper.py#46\46]8;;\
#            /content/LivePortrait/pretrained_weights/
#            liveportrait/base_models/appearance_featu
#            re_extractor.pth done.
# [14:06:25] Load motion_extractor from                ]8;id=478113;file:///content/LivePortrait/src/live_portrait_wrapper.py\live_portrait_wrapper.py]8;;\:]8;id=994933;file:///content/LivePortrait/src/live_portrait_wrapper.py#49\49]8;;\
#            /content/LivePortrait/pretrained_weights/
#            liveportrait/base_models/motion_extractor
#            .pth done.
#            Load warping_module from                  ]8;id=527699;file:///content/LivePortrait/src/live_portrait_wrapper.py\live_portrait_wrapper.py]8;;\:]8;id=473252;file:///content/LivePortrait/src/live_portrait_wrapper.py#52\52]8;;\
#            /content/LivePortrait/pretrained_weights/
#            liveportrait/base_models/warping_module.p
#            th done.
# [14:06:26] Load spade_generator from                 ]8;id=498448;file:///content/LivePortrait/src/live_portrait_wrapper.py\live_portrait_wrapper.py]8;;\:]8;id=592871;file:///content/LivePortrait/src/live_portrait_wrapper.py#55\55]8;;\
#            /content/LivePortrait/pretrained_weights/
#            liveportrait/base_models/spade_generator.
#            pth done.
#            Load stitching_retargeting_module from    ]8;id=677764;file:///content/LivePortrait/src/live_portrait_wrapper.py\live_portrait_wrapper.py]8;;\:]8;id=306910;file:///content/LivePortrait/src/live_portrait_wrapper.py#59\59]8;;\
#            /content/LivePortrait/pretrained_weights/
#            liveportrait/retargeting_models/stitching
#            _retargeting_module.pth done.
# /usr/local/lib/python3.11/dist-packages/onnxruntime/capi/onnxruntime_inference_collection.py:121: UserWarning: Specified provider 'CUDAExecutionProvider' is not in available provider names.Available providers: 'AzureExecutionProvider, CPUExecutionProvider'
#   warnings.warn(
#            FaceAnalysisDIY warmup time: 0.242s           ]8;id=338005;file:///content/LivePortrait/src/utils/face_analysis_diy.py\face_analysis_diy.py]8;;\:]8;id=315595;file:///content/LivePortrait/src/utils/face_analysis_diy.py#79\79]8;;\
# [14:06:27] LandmarkRunner warmup time: 0.147s        ]8;id=894711;file:///content/LivePortrait/src/utils/human_landmark_runner.py\human_landmark_runner.py]8;;\:]8;id=225082;file:///content/LivePortrait/src/utils/human_landmark_runner.py#95\95]8;;\
# ⚠️ BEFORE EXECUTE
#            Load source image from                   ]8;id=133581;file:///content/LivePortrait/src/live_portrait_pipeline.py\live_portrait_pipeline.py]8;;\:]8;id=138980;file:///content/LivePortrait/src/live_portrait_pipeline.py#90\90]8;;\
#            /content/LivePortrait/src/config/../../a
#            ssets/examples/source/s0.jpg
#            Load driving video from:                ]8;id=831323;file:///content/LivePortrait/src/live_portrait_pipeline.py\live_portrait_pipeline.py]8;;\:]8;id=420440;file:///content/LivePortrait/src/live_portrait_pipeline.py#133\133]8;;\
#            /content/LivePortrait/src/config/../../
#            assets/examples/driving/d0.mp4, FPS is
#            25
#            Start making driving motion template... ]8;id=19222;file:///content/LivePortrait/src/live_portrait_pipeline.py\live_portrait_pipeline.py]8;;\:]8;id=733053;file:///content/LivePortrait/src/live_portrait_pipeline.py#144\144]8;;\
# Making motion templates... ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:02
# [14:06:44] Dump motion template to                 ]8;id=229440;file:///content/LivePortrait/src/live_portrait_pipeline.py\live_portrait_pipeline.py]8;;\:]8;id=685911;file:///content/LivePortrait/src/live_portrait_pipeline.py#172\172]8;;\
#            /content/LivePortrait/src/config/../../
#            assets/examples/driving/d0.pkl
#            Prepared pasteback mask done.           ]8;id=418179;file:///content/LivePortrait/src/live_portrait_pipeline.py\live_portrait_pipeline.py]8;;\:]8;id=434387;file:///content/LivePortrait/src/live_portrait_pipeline.py#183\183]8;;\
# [14:06:45] The animated video consists of 78       ]8;id=968126;file:///content/LivePortrait/src/live_portrait_pipeline.py\live_portrait_pipeline.py]8;;\:]8;id=37680;file:///content/LivePortrait/src/live_portrait_pipeline.py#270\270]8;;\
#            frames.
# 🚀Animating... ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:12
# Concatenating result... ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
# Writing ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
# Writing ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
# [14:07:02] Animated template:                      ]8;id=398971;file:///content/LivePortrait/src/live_portrait_pipeline.py\live_portrait_pipeline.py]8;;\:]8;id=650140;file:///content/LivePortrait/src/live_portrait_pipeline.py#503\503]8;;\
#            /content/LivePortrait/src/config/../../
#            assets/examples/driving/d0.pkl, you can
#            specify `-d` argument with this
#            template path next time to avoid
#            cropping video, motion making and
#            protecting privacy.
#            Animated video: animations/s0--d0.mp4   ]8;id=385288;file:///content/LivePortrait/src/live_portrait_pipeline.py\live_portrait_pipeline.py]8;;\:]8;id=237289;file:///content/LivePortrait/src/live_portrait_pipeline.py#504\504]8;;\
#            Animated video with concat:             ]8;id=925859;file:///content/LivePortrait/src/live_portrait_pipeline.py\live_portrait_pipeline.py]8;;\:]8;id=56047;file:///content/LivePortrait/src/live_portrait_pipeline.py#505\505]8;;\
#            animations/s0--d0_concat.mp4
# ⚠️ AFTER EXECUTE
# ✅ Inference Time: 35.24 seconds

# %%
# !cat log.txt
# Out:
# Inference Time: 35.24 seconds

# %%
# !python inference.py > log.txt 2>&1 &

# %%
# !tail -f log.txt
# Out:
# [14:07:40] Load appearance_feature_extractor from    live_portrait_wrapper.py:46
#            /content/LivePortrait/pretrained_weights/
#            liveportrait/base_models/appearance_featu
#            re_extractor.pth done.
#            Load motion_extractor from                live_portrait_wrapper.py:49
#            /content/LivePortrait/pretrained_weights/
#            liveportrait/base_models/motion_extractor
#            .pth done.
# [14:07:41] Load warping_module from                  live_portrait_wrapper.py:52
#            /content/LivePortrait/pretrained_weights/
#            liveportrait/base_models/warping_module.p
#            th done.
# [14:07:42] Load spade_generator from                 live_portrait_wrapper.py:55
#            /content/LivePortrait/pretrained_weights/
#            liveportrait/base_models/spade_generator.
#            pth done.
#            Load stitching_retargeting_module from    live_portrait_wrapper.py:59
#            /content/LivePortrait/pretrained_weights/
#            liveportrait/retargeting_models/stitching
#            _retargeting_module.pth done.
# /usr/local/lib/python3.11/dist-packages/onnxruntime/capi/onnxruntime_inference_collection.py:121: UserWarning: Specified provider 'CUDAExecutionProvider' is not in available provider names.Available providers: 'AzureExecutionProvider, CPUExecutionProvider'
#   warnings.warn(
# [14:07:43] FaceAnalysisDIY warmup time: 0.409s           face_analysis_diy.py:79
#            LandmarkRunner warmup time: 0.150s        human_landmark_runner.py:95
# ⚠️ BEFORE EXECUTE
#            Load source image from                   live_portrait_pipeline.py:90
#            /content/LivePortrait/src/config/../../a
#            ssets/examples/source/s0.jpg
#            Load driving video from:                live_portrait_pipeline.py:133
#            /content/LivePortrait/src/config/../../
#            assets/examples/driving/d0.mp4, FPS is
#            25
# [14:07:44] Start making driving motion template... live_portrait_pipeline.py:144
# Making motion templates... ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:01
# [14:08:01] Dump motion template to                 live_portrait_pipeline.py:172
#            /content/LivePortrait/src/config/../../
#            assets/examples/driving/d0.pkl
#            Prepared pasteback mask done.           live_portrait_pipeline.py:183
# [14:08:02] The animated video consists of 78       live_portrait_pipeline.py:270
#            frames.
# 🚀Animating... ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:12
# Concatenating result... ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
#
#
# tail: log.txt: file truncated
# Inference Time: 36.77 seconds
# ^C

# %% [markdown]
# # **Used Image for inference to portrait video**

# %% [markdown]
# ![s9.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # Referenced video to convert the above image into Live Portrait

# %% [markdown]
# **Here I am providing Google drive Link to see the output before optimizing the code**
#
# > Before

# %% [markdown]
# **Inference Time: 36.77 seconds**

# %% [markdown]
# **Click here to see the output:**
# [Output Before Optimization of code](https://drive.google.com/drive/folders/1BdwHzs1-Um0yn1j94xemvQ9WP7CSdZxX?usp=sharing)
